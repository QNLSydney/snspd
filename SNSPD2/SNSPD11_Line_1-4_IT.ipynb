# %% [markdown]
# # Laser Code

# %%
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

# %%
############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

# %% [markdown]
# # Set Instruments Code

# %%
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

params.laser_set_standard(laser, wavelength=1550e-9, power=7)
params.laser_get_standard(laser)
params.pmeter_set_standard(pmeter=pm100d, wavelength=1550e-9)
params.pmeter_set_standard(pmeter=pms120, wavelength=1550e-9)
params.MSO5_set_standard_counts(MS)
p_att.write(f'VOLT {params.device_line_1['v_attenuator_vals']['att_blue_v']}')
# yoko.current(0)
# Check shielding: box and fridge entry

# %% [markdown]
# # Import

# %%
import time
from time import sleep, monotonic
import datetime
import numpy as np
import matplotlib.pyplot as plt
import sys
import pyvisa
import qcodes as qc
from qcodes.dataset import Measurement
from qcodes.dataset import do0d
from qcodes.dataset.experiment_container import new_experiment, load_experiment_by_name
from qcodes.dataset.plotting import plot_by_id
from qcodes.dataset.data_set import load_by_id, load_by_counter
from qcodes import initialise_or_create_database_at, new_data_set, new_experiment
from qcodes.station import Station
initialise_or_create_database_at("./2026-05-11_SNSPD11.db")
import snspd
params = snspd.snspd('snspd11.yaml')

# Set up experiment
exp_name = 'SNSPD11_11_05_2026'
sample_name = '00'

try:
    exp = qc.load_experiment_by_name(exp_name, sample=sample_name)
    print('Experiment loaded. Last ID no:', exp.last_counter)
except ValueError:
    exp = new_experiment(exp_name, sample_name)
    print('Started new experiment')
# Out:
# Logging hadn't been started.
# Activating auto-logging. Current session state plus future input saved.
# Filename       : C:\Users\QNL\.qcodes\logs\command_history.log
# Mode           : append
# Output logging : True
# Raw input log  : False
# Timestamping   : True
# State          : active
# Qcodes Logfile : C:\Users\QNL\.qcodes\logs\260524-11080-qcodes.log
# Experiment loaded. Last ID no: 287

# %%
import importlib
importlib.reload(snspd)
params = snspd.snspd('snspd11.yaml')

# %%
import pyvisa
rm = pyvisa.ResourceManager()

# %%
rm.list_resources()
# Out:
# ('TCPIP0::10.196.52.98::inst0::INSTR',
#  'TCPIP0::10.196.52.96::inst0::INSTR',
#  'ASRL1::INSTR',
#  'ASRL2::INSTR',
#  'ASRL5::INSTR',
#  'ASRL6::INSTR',
#  'ASRL7::INSTR',
#  'ASRL8::INSTR',
#  'ASRL9::INSTR',
#  'ASRL10::INSTR',
#  'ASRL11::INSTR',
#  'ASRL12::INSTR',
#  'ASRL13::INSTR',
#  'TCPIP0::10.196.50.27::inst0::INSTR',
#  'USB0::0x05E6::0x2230::9010428::0::INSTR',
#  'USB0::0x1313::0x8072::1906768::0::INSTR',
#  'USB0::0x1313::0x8072::1913782::0::INSTR',
#  'USB0::0x1313::0x8078::P0033329::0::INSTR')

# %%
station = Station(config_file="friesland.yaml")
laser = station.load_instrument("laser", revive_instance=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 station = Station(config_file="friesland.yaml")
#       2 laser = station.load_instrument("laser", revive_instance=True)
#
# NameError: name 'Station' is not defined

# %% [markdown]
# # Instruments

# %%
station = Station(config_file="friesland.yaml")
dmm = station.load_instrument("dmm", revive_instance=True)
yoko = station.load_instrument("yoko", revive_instance=True)
laser = station.load_instrument("laser", revive_instance=True)
MS = station.load_instrument("osc", revive_instance=True)
pm100d = station.load_instrument("pm100d", revive_instance=True) 
pms120 = station.load_instrument("pms120", revive_instance=True)
tc = station.load_instrument("fridge", revive_instance=True)
p_att = station.load_instrument("dmm_keithley", revive_instance=True) # excluding from snapshot because none of the parameters work anyway

# %%
params.initialize_station()

# %%
params.device_line_1.keys()
# Out:
# dict_keys(['name', 'currents', 'counts_axes', 'thresholds', 'IDs'])

# %% [markdown]
# With isolation transformer connected

# %% [markdown]
# # Light Counts vs Current

# %% [markdown]
# Trying to run identical code block to ID 80 (for comparison to sweep without isolation transformer)

# %%
###### REPEAT ID 80 - identical code block ######
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

params.laser_set_standard(laser, wavelength=1550e-9, power=7)
params.laser_get_standard(laser)
params.pmeter_set_standard(pmeter=pm100d, wavelength=1550e-9)
params.pmeter_set_standard(pmeter=pms120, wavelength=1550e-9)
params.MSO5_set_standard_counts(params.device_line_1, MS)
p_att.write(f'VOLT 5') # hard coded in 5V, previously brought in variable from config 
# yoko.current(0)
# Check shielding: box and fridge entry 

############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

params.MSO5_counts_vs_current(device=params.device_line_1, n_captures=10, interval=1, osc=MS) 

############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')
# Out:
# 2026-05-24 13:51:17,248 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# Power: 7.0
# Frequency coarse: 193.4144THz
# Wavelength (calculated) is 1550.000713493928nm
# Powermeter wavelength is 1.55e-06
# Powermeter wavelength is 1.55e-06
# Laser enable status: True
# Set standard oscilloscope parameters for counts
# update station
# Starting experimental run with id: 288.
# 288
# 0.15
# This acquisition will take 10s
# 13 51
# 2026-05-24 13:51:54,218 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 52
# 2026-05-24 13:52:16,379 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 52
# 2026-05-24 13:52:38,541 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 52
# 2026-05-24 13:53:00,717 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 53
# 2026-05-24 13:53:22,895 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 53
# 2026-05-24 13:53:45,071 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 53
# 2026-05-24 13:54:07,248 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 54
# 2026-05-24 13:54:29,409 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 54
# 2026-05-24 13:54:51,570 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 55
# 2026-05-24 13:55:13,731 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 55
# 2026-05-24 13:55:35,892 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 55
# 2026-05-24 13:55:58,053 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 56
# 2026-05-24 13:56:20,213 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 56
# 2026-05-24 13:56:42,358 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 56
# 2026-05-24 13:57:04,519 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 57
# 2026-05-24 13:57:26,696 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 57
# 2026-05-24 13:57:48,873 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 58
# 2026-05-24 13:58:11,033 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 58
# 2026-05-24 13:58:33,193 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 58
# 2026-05-24 13:58:55,354 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 59
# 2026-05-24 13:59:17,514 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 59
# 2026-05-24 13:59:39,675 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 13 59
# 2026-05-24 14:00:01,836 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 0
# 2026-05-24 14:00:23,997 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 0
# 2026-05-24 14:00:46,158 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 0
# 2026-05-24 14:01:08,319 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 1
# 2026-05-24 14:01:30,480 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 1
# 2026-05-24 14:01:52,641 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 2
# 2026-05-24 14:02:14,819 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 2
# 2026-05-24 14:02:36,995 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 2
# 2026-05-24 14:02:59,156 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 3
# 2026-05-24 14:03:21,316 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 3
# 2026-05-24 14:03:43,509 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 3
# 2026-05-24 14:04:05,670 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 4
# 2026-05-24 14:04:27,831 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 4
# 2026-05-24 14:04:49,993 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 5
# 2026-05-24 14:05:12,153 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 5
# 2026-05-24 14:05:34,314 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 5
# 2026-05-24 14:05:56,476 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 6
# 2026-05-24 14:06:18,637 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 6
# 2026-05-24 14:06:40,813 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 6
# 2026-05-24 14:07:02,974 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 7
# 2026-05-24 14:07:25,134 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 7
# 2026-05-24 14:07:47,296 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 7
# 2026-05-24 14:08:09,457 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 8
# 2026-05-24 14:08:31,618 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 8
# 2026-05-24 14:08:53,795 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 9
# 2026-05-24 14:09:16,083 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 9
# 2026-05-24 14:09:38,244 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 9
# 2026-05-24 14:10:00,405 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 10
# 2026-05-24 14:10:22,566 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 10
# 2026-05-24 14:10:44,743 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 10
# 2026-05-24 14:11:06,936 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 11
# 2026-05-24 14:11:29,096 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 11
# 2026-05-24 14:11:51,257 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 12
# 2026-05-24 14:12:13,402 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 12
# 2026-05-24 14:12:35,563 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 12
# 2026-05-24 14:12:57,724 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 13
# 2026-05-24 14:13:19,885 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 13
# 2026-05-24 14:13:42,047 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.15
# This acquisition will take 10s
# 14 13
# 2026-05-24 14:14:04,192 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False

# %%
params.ramp_yoko_current(yoko, 0, 0.5e-6)
yoko.current(0)
time.sleep(60)
# Out:
# Ramping to 0

# %% [markdown]
# Trace capture - code from trace captures starting ID 231

# %%
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

params.laser_set_standard(laser, wavelength=1550e-9, power=7)
params.laser_get_standard(laser)
params.pmeter_set_standard(pmeter=pm100d, wavelength=1550e-9)
params.pmeter_set_standard(pmeter=pms120, wavelength=1550e-9)
params.MSO5_set_standard_trace(MS)
p_att.write(f'VOLT 5')
# yoko.current(0)
# Check shielding: box and fridge entry 


currents = params.device_line_1['currents'][40::2] # go from -10uA where the counts start, every second value until the end  

for curr in currents: 
    yoko.current(curr) 
    time.sleep(5)

    params.capture_trace(MS, dmm, yoko, p_att, station=None)
# Out:
# 2026-05-24 14:15:37,407 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# Power: 7.0
# Frequency coarse: 193.4144THz
# Wavelength (calculated) is 1550.000713493928nm
# Powermeter wavelength is 1.55e-06
# Powermeter wavelength is 1.55e-06
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 289.
# 289
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;1.380E-9;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 290.
# 290
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;1.060E-9;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 291.
# 291
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;440.00E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 292.
# 292
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;1.4950E-9;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 293.
# 293
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;440.00E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 294.
# 294
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;205.000E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 295.
# 295
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;1.5050E-9;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 296.
# 296
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;1.450E-9;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 297.
# 297
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;1.0150E-9;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 298.
# 298
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;1.070E-9;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 299.
# 299
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;985.000E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1

# %%
params.ramp_yoko_current(yoko, 0, 0.5e-6)
yoko.current(0)
time.sleep(60)
# Out:
# Ramping to 0

# %%
yoko.current()
# Out:
# 0.0
