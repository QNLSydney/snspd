# %% [markdown]
# # Laser Code

# %%
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

# %%
############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

# %% [markdown]
# # Set Instruments Code

# %%
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

params.laser_set_standard(laser, wavelength=1550e-9, power=7)
params.laser_get_standard(laser)
params.pmeter_set_standard(pmeter=pm100d, wavelength=1550e-9)
params.pmeter_set_standard(pmeter=pms120, wavelength=1550e-9)
params.MSO5_set_standard_counts(MS)
p_att.write(f'VOLT {params.device_line_1['v_attenuator_vals']['att_blue_v']}')
# yoko.current(0)
# Check shielding: box and fridge entry

# %% [markdown]
# # Import

# %%
import time
from time import sleep, monotonic
import datetime
import numpy as np
import matplotlib.pyplot as plt
import sys
import pyvisa
import qcodes as qc
from qcodes.dataset import Measurement
from qcodes.dataset import do0d
from qcodes.dataset.experiment_container import new_experiment, load_experiment_by_name
from qcodes.dataset.plotting import plot_by_id
from qcodes.dataset.data_set import load_by_id, load_by_counter
from qcodes import initialise_or_create_database_at, new_data_set, new_experiment
from qcodes.station import Station
initialise_or_create_database_at("./2026-05-11_SNSPD11.db")
import snspd
params = snspd.snspd('snspd11.yaml')

# Set up experiment
exp_name = 'SNSPD11_11_05_2026'
sample_name = '00'

try:
    exp = qc.load_experiment_by_name(exp_name, sample=sample_name)
    print('Experiment loaded. Last ID no:', exp.last_counter)
except ValueError:
    exp = new_experiment(exp_name, sample_name)
    print('Started new experiment')
# Out:
# Logging hadn't been started.
# Activating auto-logging. Current session state plus future input saved.
# Filename       : C:\Users\QNL\.qcodes\logs\command_history.log
# Mode           : append
# Output logging : True
# Raw input log  : False
# Timestamping   : True
# State          : active
# Qcodes Logfile : C:\Users\QNL\.qcodes\logs\260522-14708-qcodes.log
# Experiment loaded. Last ID no: 274

# %%
import importlib
importlib.reload(snspd)
params = snspd.snspd('snspd11.yaml')

# %%
import pyvisa
rm = pyvisa.ResourceManager()

# %%
rm.list_resources()
# Out:
# ('TCPIP0::10.196.52.98::inst0::INSTR',
#  'TCPIP0::10.196.52.96::inst0::INSTR',
#  'ASRL1::INSTR',
#  'ASRL2::INSTR',
#  'ASRL5::INSTR',
#  'ASRL6::INSTR',
#  'ASRL7::INSTR',
#  'ASRL8::INSTR',
#  'ASRL9::INSTR',
#  'ASRL10::INSTR',
#  'ASRL11::INSTR',
#  'ASRL12::INSTR',
#  'ASRL13::INSTR',
#  'TCPIP0::10.196.50.27::inst0::INSTR',
#  'USB0::0x05E6::0x2230::9010428::0::INSTR',
#  'USB0::0x1313::0x8072::1906768::0::INSTR',
#  'USB0::0x1313::0x8072::1913782::0::INSTR',
#  'USB0::0x1313::0x8078::P0033329::0::INSTR')

# %%
station = Station(config_file="friesland.yaml")
laser = station.load_instrument("laser", revive_instance=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 station = Station(config_file="friesland.yaml")
#       2 laser = station.load_instrument("laser", revive_instance=True)
#
# NameError: name 'Station' is not defined

# %% [markdown]
# # Instruments

# %%
station = Station(config_file="friesland.yaml")
dmm = station.load_instrument("dmm", revive_instance=True)
yoko = station.load_instrument("yoko", revive_instance=True)
laser = station.load_instrument("laser", revive_instance=True)
MS = station.load_instrument("osc", revive_instance=True)
pm100d = station.load_instrument("pm100d", revive_instance=True) 
pms120 = station.load_instrument("pms120", revive_instance=True)
tc = station.load_instrument("fridge", revive_instance=True)
p_att = station.load_instrument("dmm_keithley", revive_instance=True) # excluding from snapshot because none of the parameters work anyway

# %%
params.initialize_station()

# %% [markdown]
# With isolation transformer connected

# %% [markdown]
# # Light Counts vs Current

# %% [markdown]
# Trying to run

# %%
###### REPEAT ID 252 - identical code block ######
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

params.laser_set_standard(laser, wavelength=1550e-9, power=7)
params.laser_get_standard(laser)
params.pmeter_set_standard(pmeter=pm100d, wavelength=1550e-9)
params.pmeter_set_standard(pmeter=pms120, wavelength=1550e-9)
params.MSO5_set_standard_counts(device=params.device_line_2, MS=MS)
p_att.write(f'VOLT 5')
# yoko.current(0)
# Check shielding: box and fridge entry 

############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

params.MSO5_counts_vs_current(device=params.device_line_2, n_captures=10, interval=1) 

############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')
# Out:
# 2026-05-22 15:46:29,478 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# Power: 7.0
# Frequency coarse: 193.4144THz
# Wavelength (calculated) is 1550.000713493928nm
# Powermeter wavelength is 1.55e-06
# Powermeter wavelength is 1.55e-06
# Laser enable status: True
# Set standard oscilloscope parameters for counts
# update station
# Starting experimental run with id: 275.
# 275
# 0.05

# %% [markdown]
# # OLD

# %% [markdown]
# Trying to reproduce results for ID 246 and 252.

# %%
params.device_line_2['thresholds_error_test']
# Out:
# {'range1': {'current': 0,
#   'threshold1': '24e-3',
#   'threshold2': '18e-3',
#   'v_scale': '50e-3'}}

# %%
params.ramp_yoko_current(yoko, 0, 0.5e-6)
print(yoko.current())
yoko.current(0)
# Out:
# Ramping to 0
# 5e-07

# %%
yoko.current(-9.5e-6)
threshold1, threshold2, v_scale = params.set_thresholds(MS, yoko, params.device_line_2['thresholds_error_test'])

MS.write(f'SEARCH:SEARCH1:TRIGger:A:EDGE:THReshold {threshold1}')
MS.write(f'SEARCH:SEARCH2:TRIGger:A:EDGE:THReshold {threshold2}')

# %%
laser.enable()
# Out:
# True

# %%
yoko.current(-9.5e-6)
threshold1, threshold2, v_scale = params.set_thresholds(MS, yoko, params.device_line_2['thresholds'])

MS.write(f'SEARCH:SEARCH1:TRIGger:A:EDGE:THReshold {threshold1}')
MS.write(f'SEARCH:SEARCH2:TRIGger:A:EDGE:THReshold {threshold2}')

# %%
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')
# Out:
# Laser enable status: False

# %% [markdown]
# Shows that ID 246 was incorrect - thresholds were set low enough to count undershoot

# %% [markdown]
# Full sweep repeat ID 246

# %%
###### REPEAT ID 246 - identical code block except thresholds #####
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

params.laser_set_standard(laser, wavelength=1550e-9, power=7)
params.laser_get_standard(laser)
params.pmeter_set_standard(pmeter=pm100d, wavelength=1550e-9)
params.pmeter_set_standard(pmeter=pms120, wavelength=1550e-9)
params.MSO5_set_standard_counts(device=params.device_line_2, MS=MS)
p_att.write(f'VOLT 5')
# yoko.current(0)
# Check shielding: box and fridge entry 

############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

params.MSO5_counts_vs_current(device=params.device_line_2, n_captures=10, interval=1, thresholds=params.device_line_2['thresholds_error_test']) 

############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')
# Out:
# 2026-05-20 11:40:44,810 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# Power: 7.0
# Frequency coarse: 193.4144THz
# Wavelength (calculated) is 1550.000713493928nm
# Powermeter wavelength is 1.55e-06
# Powermeter wavelength is 1.55e-06
# Laser enable status: True
# Set standard oscilloscope parameters for counts
# update station
# Starting experimental run with id: 270.
# 270
# 0.05
# This acquisition will take 10s
# 11 41
# 2026-05-20 11:41:21,768 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 11 41
# 2026-05-20 11:41:43,931 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 11 41
# 2026-05-20 11:42:06,078 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 11 42
# 2026-05-20 11:42:28,241 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-20 11:42:30,273 ¦ qcodes.dataset.measurements ¦ WARNING ¦ measurements ¦ __exit__ ¦ 758 ¦ An exception occurred in measurement with guid: a4a7ce04-0000-0000-0000-019e430b07a5;
# Traceback:
# Traceback (most recent call last):
#   File "D:\SNSPD\SNSPD2\snspd.py", line 411, in MSO5_counts_vs_current
#     time.sleep(2)
#     ~~~~~~~~~~^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 20
#      16 laser.enable(True)
#      17 print(f'Laser enable status: {laser.enable()}')
#      18 time.sleep(10)
#      19
# ---> 20 params.MSO5_counts_vs_current(device=params.device_line_2, n_captures=10, interval=1, thresholds=params.device_line_2['thresholds_error_test'])
#      21
#      22 ############################ TURN LASER OFF ############################
#      23 laser.enable(False)
#
# File D:\SNSPD\SNSPD2\snspd.py:411, in snspd.MSO5_counts_vs_current(self, device, n_captures, interval, osc, dmm, yoko, pmeter90, currents, thresholds, station)
#     407 for current in currents: # <- sweep voltage applied to attenuator
#     408
#     409     # Set current
#     410     yoko.current(current)
# --> 411     time.sleep(2)
#     413     # Setting thresholds
#     414     threshold1, threshold2, v_scale = self.set_thresholds(osc, yoko, thresholds)
#
# KeyboardInterrupt:

# %%
###### REPEAT ID 252 - identical code block ######
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

params.laser_set_standard(laser, wavelength=1550e-9, power=7)
params.laser_get_standard(laser)
params.pmeter_set_standard(pmeter=pm100d, wavelength=1550e-9)
params.pmeter_set_standard(pmeter=pms120, wavelength=1550e-9)
params.MSO5_set_standard_counts(device=params.device_line_2, MS=MS)
p_att.write(f'VOLT 5')
# yoko.current(0)
# Check shielding: box and fridge entry 

############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

params.MSO5_counts_vs_current(device=params.device_line_2, n_captures=10, interval=1) 

############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

# %% [markdown]
# # OLD

# %% [markdown]
# Redo with working counting function

# %%
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

params.laser_set_standard(laser, wavelength=1550e-9, power=7)
params.laser_get_standard(laser)
params.pmeter_set_standard(pmeter=pm100d, wavelength=1550e-9)
params.pmeter_set_standard(pmeter=pms120, wavelength=1550e-9)
params.MSO5_set_standard_counts(device=params.device_line_2, MS=MS)
p_att.write(f'VOLT 5')
# yoko.current(0)
# Check shielding: box and fridge entry 

############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

params.MSO5_counts_vs_current(device=params.device_line_2, n_captures=10, interval=1) 

############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')
# Out:
# 2026-05-19 15:48:10,656 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# Power: 7.0
# Frequency coarse: 193.4144THz
# Wavelength (calculated) is 1550.000713493928nm
# Powermeter wavelength is 1.55e-06
# Powermeter wavelength is 1.55e-06
# Laser enable status: True
# Set standard oscilloscope parameters for counts
# update station
# Starting experimental run with id: 252.
# 252
# 0.05
# This acquisition will take 10s
# 15 48
# 2026-05-19 15:48:47,748 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 48
# 2026-05-19 15:49:09,938 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 49
# 2026-05-19 15:49:32,145 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 49
# 2026-05-19 15:49:54,319 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 50
# 2026-05-19 15:50:16,477 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 50
# 2026-05-19 15:50:38,636 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 50
# 2026-05-19 15:51:00,875 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 51
# 2026-05-19 15:51:23,048 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 51
# 2026-05-19 15:51:45,239 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 51
# 2026-05-19 15:52:07,414 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 52
# 2026-05-19 15:52:29,588 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 52
# 2026-05-19 15:52:51,762 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 53
# 2026-05-19 15:53:13,937 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 53
# 2026-05-19 15:53:36,111 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 53
# 2026-05-19 15:53:58,269 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 54
# 2026-05-19 15:54:20,428 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 54
# 2026-05-19 15:54:42,618 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 54
# 2026-05-19 15:55:04,794 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 55
# 2026-05-19 15:55:26,967 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 55
# 2026-05-19 15:55:49,125 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 56
# 2026-05-19 15:56:11,284 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 56
# 2026-05-19 15:56:33,458 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 56
# 2026-05-19 15:56:55,633 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 57
# 2026-05-19 15:57:17,840 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 57
# 2026-05-19 15:57:40,014 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 57
# 2026-05-19 15:58:02,173 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 58
# 2026-05-19 15:58:24,331 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 58
# 2026-05-19 15:58:46,506 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 58
# 2026-05-19 15:59:08,713 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 59
# 2026-05-19 15:59:30,887 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 59
# 2026-05-19 15:59:53,044 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 16 0
# 2026-05-19 16:00:15,203 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 0
# 2026-05-19 16:00:37,393 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 0
# 2026-05-19 16:00:59,567 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 1
# 2026-05-19 16:01:21,726 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 1
# 2026-05-19 16:01:43,900 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 1
# 2026-05-19 16:02:06,059 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 2
# 2026-05-19 16:02:28,234 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 2
# 2026-05-19 16:02:50,392 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 3
# 2026-05-19 16:03:12,566 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 3
# 2026-05-19 16:03:34,741 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 3
# 2026-05-19 16:03:56,915 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 4
# 2026-05-19 16:04:19,089 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 4
# 2026-05-19 16:04:41,247 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 4
# 2026-05-19 16:05:03,453 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 5
# 2026-05-19 16:05:25,612 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 5
# 2026-05-19 16:05:47,787 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 5
# 2026-05-19 16:06:09,961 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 6
# 2026-05-19 16:06:32,120 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 6
# 2026-05-19 16:06:54,278 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 7
# 2026-05-19 16:07:16,452 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 7
# 2026-05-19 16:07:38,611 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 7
# 2026-05-19 16:08:00,801 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False

# %%
laser.enable()
# Out:
# False

# %%
yoko.current(0)
time.sleep(120)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[76], line 2
#       1 yoko.current(0)
# ----> 2 time.sleep(120)
#
# KeyboardInterrupt:

# %% [markdown]
# # Dark Counts

# %%
params.MSO5_counts_vs_current(device=params.device_line_2, n_captures=60, interval=1) # 6sec per point for dark counts
# Out:
# Set standard oscilloscope parameters for counts
# update station
# Starting experimental run with id: 247.
# 247
# This acquisition will take 60s
# 14 45
# 2026-05-19 14:46:09,788 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# This acquisition will take 60s
# 14 46
# 2026-05-19 14:47:15,094 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# This acquisition will take 60s
# 14 47
# 2026-05-19 14:48:20,367 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# This acquisition will take 60s
# 14 48
# 2026-05-19 14:49:25,673 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# This acquisition will take 60s
# 14 49
# 2026-05-19 14:50:30,996 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# This acquisition will take 60s
# 14 50
# 2026-05-19 14:51:36,317 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# This acquisition will take 60s
# 14 51
# 2026-05-19 14:52:41,608 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# This acquisition will take 60s
# 14 52
# 2026-05-19 14:53:46,962 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# This acquisition will take 60s
# 14 53
# 2026-05-19 14:54:52,252 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# This acquisition will take 60s
# 14 54
# 2026-05-19 14:55:57,543 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# This acquisition will take 60s
# 14 56
# 2026-05-19 14:57:02,850 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# This acquisition will take 60s
# 14 57
# 2026-05-19 14:58:08,139 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# This acquisition will take 60s
# 14 58
# 2026-05-19 14:59:13,430 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# This acquisition will take 60s
# 14 59
# 2026-05-19 15:00:18,736 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# This acquisition will take 60s
# 15 0
# 2026-05-19 15:01:24,073 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# This acquisition will take 60s
# 15 1
# 2026-05-19 15:02:29,348 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# This acquisition will take 60s
# 15 2
# 2026-05-19 15:03:24,546 ¦ qcodes.dataset.measurements ¦ WARNING ¦ measurements ¦ __exit__ ¦ 758 ¦ An exception occurred in measurement with guid: 49c627af-0000-0000-0000-019e3e8d335c;
# Traceback:
# Traceback (most recent call last):
#   File "D:\SNSPD\SNSPD2\snspd.py", line 434, in MSO5_counts_vs_current
#     time.sleep(interval)
#     ~~~~~~~~~~^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 params.MSO5_counts_vs_current(device=params.device_line_2, n_captures=60, interval=1) # 6sec per point for dark counts
#
# File D:\SNSPD\SNSPD2\snspd.py:434, in snspd.MSO5_counts_vs_current(self, device, n_captures, interval, osc, dmm, yoko, pmeter90, currents, thresholds, station)
#     430 counts2= []
#     433 for i in range(n_captures):
# --> 434     time.sleep(interval)
#     436     # Extract counts
#     437     count1 = int(osc.ask("SEARCH:SEARCH1:TOTal?"))
#
# KeyboardInterrupt:

# %%
params.device_line_2['currents'][15::5]
# Out:
# [-3.75e-06,
#  -5e-06,
#  -6.25e-06,
#  -7.5e-06,
#  -8.75e-06,
#  -1e-05,
#  -1.125e-05,
#  -1.25e-05]

# %%
params.MSO5_counts_vs_current(device=params.device_line_2, n_captures=10, interval=1, currents=params.device_line_2['currents'][15::5]) # 6sec per point for dark counts
# Out:
# Set standard oscilloscope parameters for counts
# update station
# Starting experimental run with id: 250.
# 250
# 0.05
# This acquisition will take 10s
# 15 25
# 2026-05-19 15:25:55,912 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 26
# 2026-05-19 15:26:18,102 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 26
# 2026-05-19 15:26:40,260 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 26
# 2026-05-19 15:27:02,435 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 27
# 2026-05-19 15:27:24,594 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 15 27
# 2026-05-19 15:27:46,800 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 15 27
# 2026-05-19 15:28:08,974 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 15 28
# 2026-05-19 15:28:31,149 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()

# %% [markdown]
# Dark counts vs current

# %%
params.MSO5_counts_vs_current(device=params.device_line_2, n_captures=60, interval=1) # 6sec per point for dark counts

# %% [markdown]
# # Counts vs Attenuation

# %%
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

params.laser_set_standard(laser, wavelength=1550e-9, power=7)
params.laser_get_standard(laser)
params.pmeter_set_standard(pmeter=pm100d, wavelength=1550e-9)
params.pmeter_set_standard(pmeter=pms120, wavelength=1550e-9)
params.MSO5_set_standard_counts(device=params.device_line_2, MS=MS)
yoko.current(0) # <- set to point of max SDE in current sweep 
# Check shielding: box and fridge entry 

v_att = params.att_blue_v_attenuator_range
v_att_range = np.arange(v_att['start'], v_att['stop'], v_att['step'])

############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

params.MSO5_counts_vs_attenuation(MS, dmm, yoko, p_att, pmeter90=pms120, device=params.device_line_2, v_att_range=v_att_range, n_captures=10, interval=1, current=-9.5e-6, station=station)

############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')
# Out:
# 2026-05-19 16:40:20,231 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# Power: 7.0
# Frequency coarse: 193.4144THz
# Wavelength (calculated) is 1550.000713493928nm
# Powermeter wavelength is 1.55e-06
# Powermeter wavelength is 1.55e-06
# Laser enable status: True
# Set standard oscilloscope parameters for counts
# update station
# Starting experimental run with id: 253.
# 253
# Current is -9.5e-06
# Starting V=5.5
# 0.1
# This acquisition will take 10s
# 16 40
# 2026-05-19 16:40:55,270 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=5.45
# 0.1
# This acquisition will take 10s
# 16 41
# 2026-05-19 16:41:11,424 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=5.4
# 0.1
# This acquisition will take 10s
# 16 41
# 2026-05-19 16:41:27,579 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=5.35
# 0.1
# This acquisition will take 10s
# 16 41
# 2026-05-19 16:41:43,750 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=5.3
# 0.1
# This acquisition will take 10s
# 16 41
# 2026-05-19 16:41:59,920 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=5.25
# 0.1
# This acquisition will take 10s
# 16 42
# 2026-05-19 16:42:16,074 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=5.2
# 0.1
# This acquisition will take 10s
# 16 42
# 2026-05-19 16:42:32,229 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=5.15
# 0.1
# This acquisition will take 10s
# 16 42
# 2026-05-19 16:42:48,399 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=5.1
# 0.1
# This acquisition will take 10s
# 16 42
# 2026-05-19 16:43:04,570 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=5.05
# 0.1
# This acquisition will take 10s
# 16 43
# 2026-05-19 16:43:20,724 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=5
# 0.1
# This acquisition will take 10s
# 16 43
# 2026-05-19 16:43:36,879 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.95
# 0.1
# This acquisition will take 10s
# 16 43
# 2026-05-19 16:43:53,049 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.9
# 0.1
# This acquisition will take 10s
# 16 43
# 2026-05-19 16:44:09,220 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.85
# 0.1
# This acquisition will take 10s
# 16 44
# 2026-05-19 16:44:25,390 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.8
# 0.1
# This acquisition will take 10s
# 16 44
# 2026-05-19 16:44:41,544 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.75
# 0.1
# This acquisition will take 10s
# 16 44
# 2026-05-19 16:44:57,715 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.7
# 0.1
# This acquisition will take 10s
# 16 45
# 2026-05-19 16:45:13,885 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.65
# 0.1
# This acquisition will take 10s
# 16 45
# 2026-05-19 16:45:30,040 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.6
# 0.1
# This acquisition will take 10s
# 16 45
# 2026-05-19 16:45:46,211 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.55
# 0.1
# This acquisition will take 10s
# 16 45
# 2026-05-19 16:46:02,382 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.5
# 0.1
# This acquisition will take 10s
# 16 46
# 2026-05-19 16:46:18,552 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.45
# 0.1
# This acquisition will take 10s
# 16 46
# 2026-05-19 16:46:34,706 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.4
# 0.1
# This acquisition will take 10s
# 16 46
# 2026-05-19 16:46:50,893 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.35
# 0.1
# This acquisition will take 10s
# 16 46
# 2026-05-19 16:47:07,047 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.3
# 0.1
# This acquisition will take 10s
# 16 47
# 2026-05-19 16:47:23,202 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.25
# 0.1
# This acquisition will take 10s
# 16 47
# 2026-05-19 16:47:39,356 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.2
# 0.1
# This acquisition will take 10s
# 16 47
# 2026-05-19 16:47:55,527 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.15
# 0.1
# This acquisition will take 10s
# 16 48
# 2026-05-19 16:48:11,697 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.1
# 0.1
# This acquisition will take 10s
# 16 48
# 2026-05-19 16:48:27,868 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4.05
# 0.1
# This acquisition will take 10s
# 16 48
# 2026-05-19 16:48:44,055 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=4
# 0.1
# This acquisition will take 10s
# 16 48
# 2026-05-19 16:49:00,242 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=3.95
# 0.1
# This acquisition will take 10s
# 16 49
# 2026-05-19 16:49:16,396 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=3.9
# 0.1
# This acquisition will take 10s
# 16 49
# 2026-05-19 16:49:32,567 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=3.85
# 0.1
# This acquisition will take 10s
# 16 49
# 2026-05-19 16:49:48,737 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=3.8
# 0.1
# This acquisition will take 10s
# 16 49
# 2026-05-19 16:50:04,908 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=3.75
# 0.1
# This acquisition will take 10s
# 16 50
# 2026-05-19 16:50:21,062 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=3.7
# 0.1
# This acquisition will take 10s
# 16 50
# 2026-05-19 16:50:37,217 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=3.65
# 0.1
# This acquisition will take 10s
# 16 50
# 2026-05-19 16:50:53,387 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=3.6
# 0.1
# This acquisition will take 10s
# 16 50
# 2026-05-19 16:51:09,558 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=3.55
# 0.1
# This acquisition will take 10s
# 16 51
# 2026-05-19 16:51:25,728 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=3.5
# 0.1
# This acquisition will take 10s
# 16 51
# 2026-05-19 16:51:41,899 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=3.45
# 0.1
# This acquisition will take 10s
# 16 51
# 2026-05-19 16:51:58,053 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Starting V=3.4
# 0.1
# This acquisition will take 10s
# 16 52
# 2026-05-19 16:52:14,208 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False

# %%
params.ramp_yoko_current(yoko, 0, 0.5e-6)
yoko.current(0)
time.sleep(30)
# Out:
# Ramping to 0

# %% [markdown]
# # Counts vs Wavelength

# %%
p_att.write('VOLT 5')
print(f'Attenuator voltage: {p_att.ask('VOLT?')}')
yoko.current(-9.5e-6)
print(f'Current: {yoko.current()}')

l = [float(val) for val in params.laser_wav_range.values()]
laser_wav_range = np.arange(l[0], l[1]+l[2], l[2])

params.counts_vs_wavelength(MS, dmm, yoko, p_att, laser, pmeter90=pms120,
                            device=params.device_line_2, n_captures=10, interval=1, wavelength_range=laser_wav_range, station=station)

############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

params.ramp_yoko_current(yoko, 0, 0.5e-6)
yoko.current(0)
# Out:
# Attenuator voltage: 5
# Current: -9.5e-06
# Set standard oscilloscope parameters for counts
# update station
# Starting experimental run with id: 254.
# 254
# Laser enable status: False
# 1.528e-06
# Power: 7.0
# Frequency coarse: 196.1992THz
# Wavelength (calculated) is 1528.0004097876035nm
# 2026-05-19 16:54:46,677 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Powermeter wavelength is 1.528e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 16 55
# 2026-05-19 16:55:21,842 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 16:55:22,075 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.529e-06
# Power: 7.0
# Frequency coarse: 196.0709THz
# Wavelength (calculated) is 1529.0002647001672nm
# Powermeter wavelength is 1.529e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 16 55
# 2026-05-19 16:55:57,210 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 16:55:57,425 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5300000000000002e-06
# Power: 7.0
# Frequency coarse: 195.9427THz
# Wavelength (calculated) is 1530.000648148668nm
# Powermeter wavelength is 1.53e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 16 56
# 2026-05-19 16:56:32,561 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 16:56:32,777 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5310000000000002e-06
# Power: 7.0
# Frequency coarse: 195.8147THz
# Wavelength (calculated) is 1531.0007777761323nm
# Powermeter wavelength is 1.531e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 16 56
# 2026-05-19 16:57:07,924 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 16:57:08,143 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5320000000000003e-06
# Power: 7.0
# Frequency coarse: 195.6869THz
# Wavelength (calculated) is 1532.0006500179622nm
# Powermeter wavelength is 1.532e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 16 57
# 2026-05-19 16:57:43,277 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 16:57:43,494 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5330000000000004e-06
# Power: 7.0
# Frequency coarse: 195.5593THz
# Wavelength (calculated) is 1533.0002613018148nm
# Powermeter wavelength is 1.533e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 16 58
# 2026-05-19 16:58:18,640 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 16:58:18,861 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5340000000000005e-06
# Power: 7.0
# Frequency coarse: 195.4318THz
# Wavelength (calculated) is 1534.0003929759641nm
# Powermeter wavelength is 1.534e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 16 58
# 2026-05-19 16:58:53,986 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 16:58:54,212 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5350000000000005e-06
# Power: 7.0
# Frequency coarse: 195.3045THz
# Wavelength (calculated) is 1535.000258570591nm
# Powermeter wavelength is 1.535e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 16 59
# 2026-05-19 16:59:29,346 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 16:59:29,595 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5360000000000006e-06
# Power: 7.0
# Frequency coarse: 195.1773THz
# Wavelength (calculated) is 1536.0006414680395nm
# Powermeter wavelength is 1.536e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 16 59
# 2026-05-19 17:00:04,736 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:00:04,962 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5370000000000007e-06
# Power: 7.0
# Frequency coarse: 195.0503THz
# Wavelength (calculated) is 1537.000753139062nm
# Powermeter wavelength is 1.537e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 0
# 2026-05-19 17:00:40,101 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:00:40,313 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5380000000000008e-06
# Power: 7.0
# Frequency coarse: 194.9235THz
# Wavelength (calculated) is 1538.0005899750415nm
# Powermeter wavelength is 1.538e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 1
# 2026-05-19 17:01:15,460 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:01:15,680 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5390000000000009e-06
# Power: 7.0
# Frequency coarse: 194.7969THz
# Wavelength (calculated) is 1539.0001483596504nm
# Powermeter wavelength is 1.539e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 1
# 2026-05-19 17:01:50,809 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:01:51,031 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.540000000000001e-06
# Power: 7.0
# Frequency coarse: 194.6704THz
# Wavelength (calculated) is 1540.000215749287nm
# Powermeter wavelength is 1.54e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 2
# 2026-05-19 17:02:26,168 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:02:26,382 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.541000000000001e-06
# Power: 7.0
# Frequency coarse: 194.54399999999998THz
# Wavelength (calculated) is 1541.0007915947035nm
# Powermeter wavelength is 1.541e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 2
# 2026-05-19 17:03:01,520 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:03:01,750 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.542000000000001e-06
# Power: 7.0
# Frequency coarse: 194.4179THz
# Wavelength (calculated) is 1542.0002890680335nm
# Powermeter wavelength is 1.542e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 3
# 2026-05-19 17:03:36,878 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:03:37,100 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5430000000000012e-06
# Power: 7.0
# Frequency coarse: 194.2919THz
# Wavelength (calculated) is 1543.000289770186nm
# Powermeter wavelength is 1.543e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 4
# 2026-05-19 17:04:12,257 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:04:12,483 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5440000000000012e-06
# Power: 7.0
# Frequency coarse: 194.166THz
# Wavelength (calculated) is 1544.0007931357704nm
# Powermeter wavelength is 1.544e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 4
# 2026-05-19 17:04:47,625 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:04:47,850 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5450000000000013e-06
# Power: 7.0
# Frequency coarse: 194.0404THz
# Wavelength (calculated) is 1545.0002061426383nm
# Powermeter wavelength is 1.545e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 5
# 2026-05-19 17:05:22,986 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:05:23,216 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5460000000000014e-06
# Power: 7.0
# Frequency coarse: 193.9149THz
# Wavelength (calculated) is 1546.0001165459694nm
# Powermeter wavelength is 1.546e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 5
# 2026-05-19 17:05:58,351 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:05:58,568 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5470000000000015e-06
# Power: 7.0
# Frequency coarse: 193.7895THz
# Wavelength (calculated) is 1547.0005237641874nm
# Powermeter wavelength is 1.547e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 6
# 2026-05-19 17:06:33,694 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:06:33,919 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5480000000000015e-06
# Power: 7.0
# Frequency coarse: 193.6643THz
# Wavelength (calculated) is 1548.0006278906335nm
# Powermeter wavelength is 1.548e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 6
# 2026-05-19 17:07:09,054 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:07:09,286 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5490000000000016e-06
# Power: 7.0
# Frequency coarse: 193.5393THz
# Wavelength (calculated) is 1549.0004252366314nm
# Powermeter wavelength is 1.549e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 7
# 2026-05-19 17:07:44,432 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:07:44,654 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5500000000000017e-06
# Power: 7.0
# Frequency coarse: 193.4144THz
# Wavelength (calculated) is 1550.000713493928nm
# Powermeter wavelength is 1.55e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 8
# 2026-05-19 17:08:19,796 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:08:20,020 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5510000000000018e-06
# Power: 7.0
# Frequency coarse: 193.28969999999998THz
# Wavelength (calculated) is 1551.000689638403nm
# Powermeter wavelength is 1.551e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 8
# 2026-05-19 17:08:55,159 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:08:55,387 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5520000000000018e-06
# Power: 7.0
# Frequency coarse: 193.1652THz
# Wavelength (calculated) is 1552.0003499595166nm
# Powermeter wavelength is 1.552e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 9
# 2026-05-19 17:09:30,509 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:09:30,723 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.553000000000002e-06
# Power: 7.0
# Frequency coarse: 193.0408THz
# Wavelength (calculated) is 1553.000495232096nm
# Powermeter wavelength is 1.553e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 9
# 2026-05-19 17:10:05,859 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:10:06,089 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.554000000000002e-06
# Power: 7.0
# Frequency coarse: 192.9166THz
# Wavelength (calculated) is 1554.0003193089658nm
# Powermeter wavelength is 1.554e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 10
# 2026-05-19 17:10:41,223 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:10:41,440 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.555000000000002e-06
# Power: 7.0
# Frequency coarse: 192.7925THz
# Wavelength (calculated) is 1555.0006250243136nm
# Powermeter wavelength is 1.555e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 11
# 2026-05-19 17:11:16,575 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:11:16,792 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5560000000000021e-06
# Power: 7.0
# Frequency coarse: 192.6686THz
# Wavelength (calculated) is 1556.0006041461868nm
# Powermeter wavelength is 1.556e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 11
# 2026-05-19 17:11:51,926 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:11:52,174 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5570000000000022e-06
# Power: 7.0
# Frequency coarse: 192.54489999999998THz
# Wavelength (calculated) is 1557.0002529280184nm
# Powermeter wavelength is 1.557e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 12
# 2026-05-19 17:12:27,308 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:12:27,525 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5580000000000023e-06
# Power: 7.0
# Frequency coarse: 192.4213THz
# Wavelength (calculated) is 1558.000377297108nm
# Powermeter wavelength is 1.558e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 12
# 2026-05-19 17:13:02,691 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:13:02,909 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5590000000000024e-06
# Power: 7.0
# Frequency coarse: 192.2979THz
# Wavelength (calculated) is 1559.000165888447nm
# Powermeter wavelength is 1.559e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 13
# 2026-05-19 17:13:38,049 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:13:38,275 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5600000000000024e-06
# Power: 7.0
# Frequency coarse: 192.1746THz
# Wavelength (calculated) is 1560.0004266953072nm
# Powermeter wavelength is 1.56e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 14
# 2026-05-19 17:14:13,410 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:14:13,642 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5610000000000025e-06
# Power: 7.0
# Frequency coarse: 192.0515THz
# Wavelength (calculated) is 1561.0003462612892nm
# Powermeter wavelength is 1.561e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 14
# 2026-05-19 17:14:48,787 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:14:49,008 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5620000000000026e-06
# Power: 7.0
# Frequency coarse: 191.92849999999999THz
# Wavelength (calculated) is 1562.00073464858nm
# Powermeter wavelength is 1.562e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 15
# 2026-05-19 17:15:24,141 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:15:24,359 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5630000000000027e-06
# Power: 7.0
# Frequency coarse: 191.8057THz
# Wavelength (calculated) is 1563.0007763064393nm
# Powermeter wavelength is 1.563e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 15
# 2026-05-19 17:15:59,507 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:15:59,727 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5640000000000027e-06
# Power: 7.0
# Frequency coarse: 191.6831THz
# Wavelength (calculated) is 1564.0004674381833nm
# Powermeter wavelength is 1.564e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 16
# 2026-05-19 17:16:34,868 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:16:35,094 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5650000000000028e-06
# Power: 7.0
# Frequency coarse: 191.5606THz
# Wavelength (calculated) is 1565.0006212133394nm
# Powermeter wavelength is 1.565e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 17
# 2026-05-19 17:17:10,228 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
#
# 2026-05-19 17:17:10,445 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# 1.5660000000000029e-06
# Power: 7.0
# Frequency coarse: 191.4383THz
# Wavelength (calculated) is 1566.0004189339331nm
# Powermeter wavelength is 1.566e-06
# Laser enable status: True
# 0.1
# This acquisition will take 10s
# 17 17
# 2026-05-19 17:17:45,579 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# Ramping to 0

# %%
params.ramp_yoko_current(yoko, 0, 0.5e-6)
yoko.current(0)
time.sleep(30)
# Out:
# Ramping to 0

# %%
time.sleep(20)

# %% [markdown]
# # Traces

# %%
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

params.laser_set_standard(laser, wavelength=1550e-9, power=7)
params.laser_get_standard(laser)
params.pmeter_set_standard(pmeter=pm100d, wavelength=1550e-9)
params.pmeter_set_standard(pmeter=pms120, wavelength=1550e-9)
params.MSO5_set_standard_trace(MS)
p_att.write(f'VOLT 5')
# yoko.current(0)
# Check shielding: box and fridge entry 

currents = params.device_line_2['currents'][30::2] # go from -7.5uA where the counts start, every second value until the end  

params.ramp_yoko_current(yoko, currents[0], 0.5e-6)

for curr in currents: 
    yoko.current(curr) 
    time.sleep(5)

    params.capture_trace(MS, dmm, yoko, p_att, station=None) # needs laser to be iniitalised in self
# Out:
# 2026-05-19 17:21:00,394 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# Power: 7.0
# Frequency coarse: 193.4144THz
# Wavelength (calculated) is 1550.000713493928nm
# Powermeter wavelength is 1.55e-06
# Powermeter wavelength is 1.55e-06
# Ramping to -7.5e-06
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 257.
# 257
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;1.5350E-9;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 258.
# 258
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;1.440E-9;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 259.
# 259
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;290.00E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 260.
# 260
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;1.460E-9;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 261.
# 261
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;90.0000000000090E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 262.
# 262
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;1.350E-9;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 263.
# 263
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;905.000E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 264.
# 264
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;1.0450E-9;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 265.
# 265
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;955.000E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 266.
# 266
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;955.000E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 267.
# 267
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;955.000E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 268.
# 268
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;955.000E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1

# %%
params.ramp_yoko_current(yoko, 0, 0.5e-6)
yoko.current(0)
time.sleep(30)
# Out:
# Ramping to 0

# %% [markdown]
# Dark counts

# %%
params.MSO5_counts_vs_current(device=params.device_line_2, n_captures=60, interval=1) # 6sec per point for dark counts
# Out:
# Set standard oscilloscope parameters for counts
# update station
# Starting experimental run with id: 269.
# 269
# 0.05
# This acquisition will take 60s
# 17 23
# 2026-05-19 17:24:49,607 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 25
# 2026-05-19 17:26:01,911 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 26
# 2026-05-19 17:27:14,199 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 27
# 2026-05-19 17:28:26,485 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 28
# 2026-05-19 17:29:38,868 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 29
# 2026-05-19 17:30:51,187 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 31
# 2026-05-19 17:32:03,491 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 32
# 2026-05-19 17:33:15,809 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 33
# 2026-05-19 17:34:28,096 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 34
# 2026-05-19 17:35:40,383 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 35
# 2026-05-19 17:36:52,686 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 37
# 2026-05-19 17:38:05,005 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 38
# 2026-05-19 17:39:17,292 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 39
# 2026-05-19 17:40:29,595 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 40
# 2026-05-19 17:41:41,978 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 41
# 2026-05-19 17:42:54,265 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 43
# 2026-05-19 17:44:06,601 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 44
# 2026-05-19 17:45:18,919 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 45
# 2026-05-19 17:46:31,205 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 46
# 2026-05-19 17:47:43,507 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 47
# 2026-05-19 17:48:55,842 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 49
# 2026-05-19 17:50:08,129 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 50
# 2026-05-19 17:51:20,432 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 51
# 2026-05-19 17:52:32,879 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 52
# 2026-05-19 17:53:45,198 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 53
# 2026-05-19 17:54:57,485 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 55
# 2026-05-19 17:56:09,788 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 56
# 2026-05-19 17:57:22,107 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 57
# 2026-05-19 17:58:34,378 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 58
# 2026-05-19 17:59:46,682 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 17 59
# 2026-05-19 18:00:59,032 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 60s
# 18 1
# 2026-05-19 18:02:11,320 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 2
# 2026-05-19 18:03:23,655 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 3
# 2026-05-19 18:04:35,991 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 4
# 2026-05-19 18:05:48,262 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 6
# 2026-05-19 18:07:00,549 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 7
# 2026-05-19 18:08:12,915 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 8
# 2026-05-19 18:09:25,186 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 9
# 2026-05-19 18:10:37,456 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 10
# 2026-05-19 18:11:49,759 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 12
# 2026-05-19 18:13:02,077 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 13
# 2026-05-19 18:14:14,434 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 14
# 2026-05-19 18:15:26,747 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 15
# 2026-05-19 18:16:39,050 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 16
# 2026-05-19 18:17:51,321 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 18
# 2026-05-19 18:19:03,656 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 19
# 2026-05-19 18:20:15,974 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 20
# 2026-05-19 18:21:28,244 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 21
# 2026-05-19 18:22:40,579 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 22
# 2026-05-19 18:23:52,930 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 24
# 2026-05-19 18:25:05,217 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 25
# 2026-05-19 18:26:17,487 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 60s
# 18 26
# 2026-05-19 18:27:29,853 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()

# %% [markdown]
# # Wavelength Sweep 2

# %% [markdown]
# Checked powermeter90 and thresholds, all seemed to set. Perhaps device latched. Running again to check.

# %%
params.ramp_yoko_current(yoko, -9.5e-6, 0.5e-6)
print(yoko.current())
# Out:
# Ramping to -9.5e-06
# -9.5e-06

# %%
params.ramp_yoko_current(yoko, 0, 0.5e-6)
print(yoko.current())
yoko.current(0)
time.sleep(60)
params.ramp_yoko_current(yoko, -9.5e-6, 0.5e-6)
print(yoko.current())
# Out:
# Ramping to 0
# 5e-07
# Ramping to -9.5e-06
# -1e-05

# %%
laser.enable()
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 laser.enable()
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\qcodes\parameters\parameter_base.py:696, in ParameterBase.__call__(self, *args, **kwargs)
#     694 if len(args) == 0 and len(kwargs) == 0:
#     695     if self.gettable:
# --> 696         return self.get()
#     697     else:
#     698         raise NotImplementedError(f"no get cmd found in Parameter {self.name}")
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\qcodes\parameters\parameter_base.py:916, in ParameterBase._wrap_get.<locals>.get_wrapper(*args, **kwargs)
#     914 except Exception as e:
#     915     e.args = (*e.args, f"getting {self}")
# --> 916     raise e
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\qcodes\parameters\parameter_base.py:903, in ParameterBase._wrap_get.<locals>.get_wrapper(*args, **kwargs)
#     898     raise NotImplementedError(
#     899         f"Trying to get an abstract parameter: {self.full_name}"
#     900     )
#     901 try:
#     902     # There might be cases where a .get also has args/kwargs
# --> 903     raw_value = get_function(*args, **kwargs)
#     905     value = self._from_raw_value_to_value(raw_value)
#     907     if self._validate_on_get:
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\qcodes\parameters\command.py:213, in Command.__call__(self, *args)
#     211 if len(args) != self.arg_count:
#     212     raise TypeError(f"command takes exactly {self.arg_count} args")
# --> 213 return self.exec_function(*args)
#
# File D:\SNSPD\SNSPD2\PPCL550.py:157, in PPCL550.__init__.<locals>.<lambda>()
#     146 self.add_parameter('FThermTh',
#     147                     get_cmd=lambda: self._get_value(0x26)/100.0,
#     148                     docstring='Maximum thermal deviation for fatal alarm.',
#     149                    unit='C',
#     150                     )
#     151 self.add_parameter('WThermTh',
#     152                     get_cmd=lambda: self._get_value(0x26)/100.0,
#     153                     docstring='Maximum frequency deviation for fatal alarm.',
#     154                    unit='C',
#     155                     )
#     156 self.add_parameter('enable',
# --> 157                    get_cmd=lambda: self._get_value(0x32),
#     158                    set_cmd=lambda x: self._set_value(0x32, x),
#     159                    set_parser=int,
#     160                    label='Enable output',
#     161                    val_mapping=create_on_off_val_mapping(on_val=8, off_val=0)
#     162 )
#     164 self.add_parameter('_FCF1',
#     165                    snapshot_exclude=True,
#     166                    get_cmd=lambda: self._get_value(0x35),
#    (...)    172                    docstring='Do not use directly. Use `frequency_coarse` instead'
#     173 )
#     175 self.add_parameter('_FCF2',
#     176                    snapshot_exclude=True,
#     177                    get_cmd=lambda: self._get_value(0x36),
#    (...)    183                    docstring='Do not use directly. Use `frequency_coarse` instead'
#     184 )
#
# File D:\SNSPD\SNSPD2\PPCL550.py:247, in PPCL550._get_value(self, register, signed)
#     242 def _get_value(self, register, signed=False) -> int:
#     243     """
#     244     Only get the value part of a register
#     245     Uses _get_register to obtain _get_value
#     246     """
# --> 247     reg   = self._get_register(register)
#     248     if signed:
#     249         value = int.from_bytes(reg, byteorder='big', signed=True)
#
# File D:\SNSPD\SNSPD2\PPCL550.py:224, in PPCL550._get_register(self, register)
#     220 """
#     221 Get the contents of the specified register
#     222 """
#     223 message = bytes([checksum(0, register, 0, 0) << 4, register, 0x00, 0x00])
# --> 224 self.visa_handle.write_raw(message)
#     225 with warnings.catch_warnings():
#     226     warnings.simplefilter("ignore")
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:173, in MessageBasedResource.write_raw(self, message)
#     159 def write_raw(self, message: bytes) -> int:
#     160     """Write a byte message to the device.
#     161
#     162     Parameters
#    (...)    171
#     172     """
# --> 173     return self.visalib.write(self.session, message)[0]
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\ctwrapper\functions.py:2798, in write(library, session, data)
#    2796 return_count = ViUInt32()
#    2797 # [ViSession, ViBuf, ViUInt32, ViPUInt32]
# -> 2798 ret = library.viWrite(session, data, len(data), byref(return_count))
#    2799 return return_count.value, ret
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\ctwrapper\highlevel.py:227, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     224         # Set session back to a safe value
#     225         session = None
# --> 227 return self.handle_return_value(session, ret_value)
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\highlevel.py:252, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     249     self._last_status_in_session[session] = rv
#     251 if rv < 0:
# --> 252     raise errors.VisaIOError(rv)
#     254 if rv in self.issue_warning_on:
#     255     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: ('VI_ERROR_CONN_LOST (-1073807194): The connection for the given session has been lost.', 'getting laser_enable')

# %%
p_att.write('VOLT 5')
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 p_att.write('VOLT 5')
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\qcodes\instrument\instrument.py:401, in Instrument.write(self, cmd)
#     396 except Exception as e:
#     397     e.args = (
#     398         *e.args,
#     399         f"writing {cmd!r} to {self!r}",
#     400     )
# --> 401     raise e
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\qcodes\instrument\instrument.py:395, in Instrument.write(self, cmd)
#     379 """
#     380 Write a command string with NO response to the hardware.
#     381
#    (...)    392
#     393 """
#     394 try:
# --> 395     self.write_raw(cmd)
#     396 except Exception as e:
#     397     e.args = (
#     398         *e.args,
#     399         f"writing {cmd!r} to {self!r}",
#     400     )
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\qcodes\instrument\visa.py:377, in VisaInstrument.write_raw(self, cmd)
#     373 with DelayedKeyboardInterrupt(
#     374     context={"instrument": self.name, "reason": "Visa Instrument write"}
#     375 ):
#     376     self.visa_log.debug(f"Writing: {cmd}")
# --> 377     self.visa_handle.write(cmd)
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:213, in MessageBasedResource.write(self, message, termination, encoding)
#     207         warnings.warn(
#     208             "write message already ends with termination characters",
#     209             stacklevel=2,
#     210         )
#     211     message += term
# --> 213 count = self.write_raw(message.encode(enco))
#     215 return count
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:173, in MessageBasedResource.write_raw(self, message)
#     159 def write_raw(self, message: bytes) -> int:
#     160     """Write a byte message to the device.
#     161
#     162     Parameters
#    (...)    171
#     172     """
# --> 173     return self.visalib.write(self.session, message)[0]
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\ctwrapper\functions.py:2798, in write(library, session, data)
#    2796 return_count = ViUInt32()
#    2797 # [ViSession, ViBuf, ViUInt32, ViPUInt32]
# -> 2798 ret = library.viWrite(session, data, len(data), byref(return_count))
#    2799 return return_count.value, ret
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\ctwrapper\highlevel.py:227, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     224         # Set session back to a safe value
#     225         session = None
# --> 227 return self.handle_return_value(session, ret_value)
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\highlevel.py:252, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     249     self._last_status_in_session[session] = rv
#     251 if rv < 0:
# --> 252     raise errors.VisaIOError(rv)
#     254 if rv in self.issue_warning_on:
#     255     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: ('VI_ERROR_NCIC (-1073807264): The interface associated with this session is not currently the controller in charge.', "writing 'VOLT 5' to <Keithley2000: dmm_keithley>")

# %%
p_att.write('VOLT 5')
print(f'Attenuator voltage: {p_att.ask('VOLT?')}')
yoko.current(-9.5e-6)
print(f'Current: {yoko.current()}')

l = [float(val) for val in params.laser_wav_range.values()]
laser_wav_range = np.arange(l[0], l[1]+l[2], l[2])

params.counts_vs_wavelength(MS, dmm, yoko, p_att, laser, pmeter90=pms120,
                            device=params.device_line_2, n_captures=10, interval=1, wavelength_range=laser_wav_range, station=station)

############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

params.ramp_yoko_current(yoko, 0, 0.5e-6)
yoko.current(0)
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 p_att.write('VOLT 5')
#       2 print(f'Attenuator voltage: {p_att.ask('VOLT?')}')
#       3 yoko.current(-9.5e-6)
#       4 print(f'Current: {yoko.current()}')
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\qcodes\instrument\instrument.py:401, in Instrument.write(self, cmd)
#     396 except Exception as e:
#     397     e.args = (
#     398         *e.args,
#     399         f"writing {cmd!r} to {self!r}",
#     400     )
# --> 401     raise e
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\qcodes\instrument\instrument.py:395, in Instrument.write(self, cmd)
#     379 """
#     380 Write a command string with NO response to the hardware.
#     381
#    (...)    392
#     393 """
#     394 try:
# --> 395     self.write_raw(cmd)
#     396 except Exception as e:
#     397     e.args = (
#     398         *e.args,
#     399         f"writing {cmd!r} to {self!r}",
#     400     )
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\qcodes\instrument\visa.py:377, in VisaInstrument.write_raw(self, cmd)
#     373 with DelayedKeyboardInterrupt(
#     374     context={"instrument": self.name, "reason": "Visa Instrument write"}
#     375 ):
#     376     self.visa_log.debug(f"Writing: {cmd}")
# --> 377     self.visa_handle.write(cmd)
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:213, in MessageBasedResource.write(self, message, termination, encoding)
#     207         warnings.warn(
#     208             "write message already ends with termination characters",
#     209             stacklevel=2,
#     210         )
#     211     message += term
# --> 213 count = self.write_raw(message.encode(enco))
#     215 return count
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:173, in MessageBasedResource.write_raw(self, message)
#     159 def write_raw(self, message: bytes) -> int:
#     160     """Write a byte message to the device.
#     161
#     162     Parameters
#    (...)    171
#     172     """
# --> 173     return self.visalib.write(self.session, message)[0]
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\ctwrapper\functions.py:2798, in write(library, session, data)
#    2796 return_count = ViUInt32()
#    2797 # [ViSession, ViBuf, ViUInt32, ViPUInt32]
# -> 2798 ret = library.viWrite(session, data, len(data), byref(return_count))
#    2799 return return_count.value, ret
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\ctwrapper\highlevel.py:227, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     224         # Set session back to a safe value
#     225         session = None
# --> 227 return self.handle_return_value(session, ret_value)
#
# File ~\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\highlevel.py:252, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     249     self._last_status_in_session[session] = rv
#     251 if rv < 0:
# --> 252     raise errors.VisaIOError(rv)
#     254 if rv in self.issue_warning_on:
#     255     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: ('VI_ERROR_NCIC (-1073807264): The interface associated with this session is not currently the controller in charge.', "writing 'VOLT 5' to <Keithley2000: dmm_keithley>")
