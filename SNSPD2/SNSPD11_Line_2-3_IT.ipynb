# %% [markdown]
# # Laser Code

# %%
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

# %%
############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

# %% [markdown]
# # Set Instruments Code

# %%
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

params.laser_set_standard(laser, wavelength=1550e-9, power=7)
params.laser_get_standard(laser)
params.pmeter_set_standard(pmeter=pm100d, wavelength=1550e-9)
params.pmeter_set_standard(pmeter=pms120, wavelength=1550e-9)
params.MSO5_set_standard_counts(MS)
p_att.write(f'VOLT {params.device_line_1['v_attenuator_vals']['att_blue_v']}')
# yoko.current(0)
# Check shielding: box and fridge entry

# %% [markdown]
# # Import

# %%
import time
from time import sleep, monotonic
import datetime
import numpy as np
import matplotlib.pyplot as plt
import sys
import pyvisa
import qcodes as qc
from qcodes.dataset import Measurement
from qcodes.dataset import do0d
from qcodes.dataset.experiment_container import new_experiment, load_experiment_by_name
from qcodes.dataset.plotting import plot_by_id
from qcodes.dataset.data_set import load_by_id, load_by_counter
from qcodes import initialise_or_create_database_at, new_data_set, new_experiment
from qcodes.station import Station
initialise_or_create_database_at("./2026-05-11_SNSPD11.db")
import snspd
params = snspd.snspd('snspd11.yaml')

# Set up experiment
exp_name = 'SNSPD11_11_05_2026'
sample_name = '00'

try:
    exp = qc.load_experiment_by_name(exp_name, sample=sample_name)
    print('Experiment loaded. Last ID no:', exp.last_counter)
except ValueError:
    exp = new_experiment(exp_name, sample_name)
    print('Started new experiment')
# Out:
# Logging hadn't been started.
# Activating auto-logging. Current session state plus future input saved.
# Filename       : C:\Users\QNL\.qcodes\logs\command_history.log
# Mode           : append
# Output logging : True
# Raw input log  : False
# Timestamping   : True
# State          : active
# Qcodes Logfile : C:\Users\QNL\.qcodes\logs\260522-14708-qcodes.log
# Experiment loaded. Last ID no: 274

# %%
import importlib
importlib.reload(snspd)
params = snspd.snspd('snspd11.yaml')

# %%
import pyvisa
rm = pyvisa.ResourceManager()

# %%
rm.list_resources()
# Out:
# ('TCPIP0::10.196.52.98::inst0::INSTR',
#  'TCPIP0::10.196.52.96::inst0::INSTR',
#  'ASRL1::INSTR',
#  'ASRL2::INSTR',
#  'ASRL5::INSTR',
#  'ASRL6::INSTR',
#  'ASRL7::INSTR',
#  'ASRL8::INSTR',
#  'ASRL9::INSTR',
#  'ASRL10::INSTR',
#  'ASRL11::INSTR',
#  'ASRL12::INSTR',
#  'ASRL13::INSTR',
#  'TCPIP0::10.196.50.27::inst0::INSTR',
#  'USB0::0x05E6::0x2230::9010428::0::INSTR',
#  'USB0::0x1313::0x8072::1906768::0::INSTR',
#  'USB0::0x1313::0x8072::1913782::0::INSTR',
#  'USB0::0x1313::0x8078::P0033329::0::INSTR')

# %%
station = Station(config_file="friesland.yaml")
laser = station.load_instrument("laser", revive_instance=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 station = Station(config_file="friesland.yaml")
#       2 laser = station.load_instrument("laser", revive_instance=True)
#
# NameError: name 'Station' is not defined

# %% [markdown]
# # Instruments

# %%
station = Station(config_file="friesland.yaml")
dmm = station.load_instrument("dmm", revive_instance=True)
yoko = station.load_instrument("yoko", revive_instance=True)
laser = station.load_instrument("laser", revive_instance=True)
MS = station.load_instrument("osc", revive_instance=True)
pm100d = station.load_instrument("pm100d", revive_instance=True) 
pms120 = station.load_instrument("pms120", revive_instance=True)
tc = station.load_instrument("fridge", revive_instance=True)
p_att = station.load_instrument("dmm_keithley", revive_instance=True) # excluding from snapshot because none of the parameters work anyway

# %%
params.initialize_station()

# %% [markdown]
# With isolation transformer connected

# %% [markdown]
# # Light Counts vs Current

# %% [markdown]
# Trying to run identical code block to ID 252

# %%
###### REPEAT ID 252 - identical code block ######
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

params.laser_set_standard(laser, wavelength=1550e-9, power=7)
params.laser_get_standard(laser)
params.pmeter_set_standard(pmeter=pm100d, wavelength=1550e-9)
params.pmeter_set_standard(pmeter=pms120, wavelength=1550e-9)
params.MSO5_set_standard_counts(device=params.device_line_2, MS=MS)
p_att.write(f'VOLT 5')
# yoko.current(0)
# Check shielding: box and fridge entry 

############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

params.MSO5_counts_vs_current(device=params.device_line_2, n_captures=10, interval=1) 

############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')
# Out:
# 2026-05-22 15:46:29,478 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# Power: 7.0
# Frequency coarse: 193.4144THz
# Wavelength (calculated) is 1550.000713493928nm
# Powermeter wavelength is 1.55e-06
# Powermeter wavelength is 1.55e-06
# Laser enable status: True
# Set standard oscilloscope parameters for counts
# update station
# Starting experimental run with id: 275.
# 275
# 0.05
# This acquisition will take 10s
# 15 46
# 2026-05-22 15:47:06,275 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 47
# 2026-05-22 15:47:28,438 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 47
# 2026-05-22 15:47:50,601 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 48
# 2026-05-22 15:48:12,764 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 48
# 2026-05-22 15:48:34,927 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 48
# 2026-05-22 15:48:57,074 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 49
# 2026-05-22 15:49:19,220 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 49
# 2026-05-22 15:49:41,383 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 49
# 2026-05-22 15:50:03,546 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 50
# 2026-05-22 15:50:25,709 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 50
# 2026-05-22 15:50:47,872 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 50
# 2026-05-22 15:51:10,034 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 51
# 2026-05-22 15:51:32,197 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 51
# 2026-05-22 15:51:54,360 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 52
# 2026-05-22 15:52:16,523 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 52
# 2026-05-22 15:52:38,686 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 52
# 2026-05-22 15:53:00,881 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 53
# 2026-05-22 15:53:23,044 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 53
# 2026-05-22 15:53:45,207 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 53
# 2026-05-22 15:54:07,353 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 54
# 2026-05-22 15:54:29,516 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 54
# 2026-05-22 15:54:51,679 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 55
# 2026-05-22 15:55:13,857 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 55
# 2026-05-22 15:55:36,020 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 55
# 2026-05-22 15:55:58,183 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 56
# 2026-05-22 15:56:20,330 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 56
# 2026-05-22 15:56:42,493 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 56
# 2026-05-22 15:57:04,656 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 57
# 2026-05-22 15:57:26,819 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 57
# 2026-05-22 15:57:48,981 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 58
# 2026-05-22 15:58:11,177 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.05
# This acquisition will take 10s
# 15 58
# 2026-05-22 15:58:33,340 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 15 58
# 2026-05-22 15:58:55,519 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 15 59
# 2026-05-22 15:59:17,697 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 15 59
# 2026-05-22 15:59:39,860 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 15 59
# 2026-05-22 16:00:02,038 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 0
# 2026-05-22 16:00:24,201 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 0
# 2026-05-22 16:00:46,348 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 0
# 2026-05-22 16:01:08,511 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 1
# 2026-05-22 16:01:30,690 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 1
# 2026-05-22 16:01:52,868 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 2
# 2026-05-22 16:02:15,031 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 2
# 2026-05-22 16:02:37,179 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 2
# 2026-05-22 16:02:59,341 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 3
# 2026-05-22 16:03:21,521 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 3
# 2026-05-22 16:03:43,699 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 3
# 2026-05-22 16:04:05,893 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 4
# 2026-05-22 16:04:28,041 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 4
# 2026-05-22 16:04:50,188 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 5
# 2026-05-22 16:05:12,350 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 5
# 2026-05-22 16:05:34,529 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 5
# 2026-05-22 16:05:56,692 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# 0.1
# This acquisition will take 10s
# 16 6
# 2026-05-22 16:06:18,854 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False

# %%
params.ramp_yoko_current(yoko, 0, 0.5e-6)
yoko.current(0)
time.sleep(60)
# Out:
# Ramping to 0

# %%
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

params.laser_set_standard(laser, wavelength=1550e-9, power=7)
params.laser_get_standard(laser)
params.pmeter_set_standard(pmeter=pm100d, wavelength=1550e-9)
params.pmeter_set_standard(pmeter=pms120, wavelength=1550e-9)
params.MSO5_set_standard_trace(MS)
p_att.write(f'VOLT 5')
# yoko.current(0)
# Check shielding: box and fridge entry 

currents = params.device_line_2['currents'][30::2] # go from -7.5uA where the counts start, every second value until the end  

params.ramp_yoko_current(yoko, currents[0], 0.5e-6)

for curr in currents: 
    yoko.current(curr) 
    time.sleep(5)

    params.capture_trace(MS, dmm, yoko, p_att, station=None) # needs laser to be iniitalised in self
# Out:
# 2026-05-22 16:07:47,097 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# Laser enable status: False
# Power: 7.0
# Frequency coarse: 193.4144THz
# Wavelength (calculated) is 1550.000713493928nm
# Powermeter wavelength is 1.55e-06
# Powermeter wavelength is 1.55e-06
# Ramping to -7.5e-06
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 276.
# 276
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;955.000E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 277.
# 277
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;955.000E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 278.
# 278
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;1.120E-9;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 279.
# 279
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;955.000E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 280.
# 280
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;240.00E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 281.
# 281
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;1.5350E-9;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 282.
# 282
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;265.000E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 283.
# 283
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;690.00E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 284.
# 284
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;955.000E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 285.
# 285
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;955.000E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 286.
# 286
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;955.000E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
# Oscilloscope set for trace capture
# update station
# Starting experimental run with id: 287.
# 287
# 1;8;BINARY;RI;INTEGER;MSB;"Ch1, DC coupling, 38.4V/div, 300ns/div, 1875 points, Sample mode";1875;Y;LINEAR;"s";1.60E-9;955.000E-12;188;"V";6.0000E-3;0.0E+0;0.0E+0;TIME;ANALOG;0.0E+0;0.0E+0;1
