# %%
import time
from time import sleep, monotonic
import datetime
import numpy as np
import matplotlib.pyplot as plt
import sys
import pyvisa
import qcodes as qc
from qcodes.dataset import Measurement
from qcodes.dataset import do0d
from qcodes.dataset.experiment_container import new_experiment, load_experiment_by_name
from qcodes.dataset.plotting import plot_by_id
from qcodes.dataset.data_set import load_by_id, load_by_counter
from qcodes import initialise_or_create_database_at, new_data_set, new_experiment
from qcodes.station import Station
initialise_or_create_database_at("./2026-05-11_SNSPD12.db")
import snspd
params = snspd.snspd('snspd12.yaml')

# Set up experiment
exp_name = 'SNSPD12_29_05_2026'
sample_name = '00'

try:
    exp = qc.load_experiment_by_name(exp_name, sample=sample_name)
    print('Experiment loaded. Last ID no:', exp.last_counter)
except ValueError:
    exp = new_experiment(exp_name, sample_name)
    print('Started new experiment')
# Out:
# Logging hadn't been started.
# Activating auto-logging. Current session state plus future input saved.
# Filename       : C:\Users\QNL\.qcodes\logs\command_history.log
# Mode           : append
# Output logging : True
# Raw input log  : False
# Timestamping   : True
# State          : active
# Qcodes Logfile : C:\Users\QNL\.qcodes\logs\260529-15848-qcodes.log
# Experiment loaded. Last ID no: 6

# %%
import importlib
importlib.reload(snspd)
params = snspd.snspd('snspd12.yaml')

# %%
station = Station(config_file="friesland.yaml")
# dmm = station.load_instrument("dmm", revive_instance=True)
# yoko = station.load_instrument("yoko", revive_instance=True)
laser = station.load_instrument("laser", revive_instance=True)
MS = station.load_instrument("osc", revive_instance=True)
pm100d = station.load_instrument("pm100d", revive_instance=True) 
pms120 = station.load_instrument("pms120", revive_instance=True)
tc = station.load_instrument("fridge", revive_instance=True)
p_att = station.load_instrument("dmm_keithley", revive_instance=True) # excluding from snapshot because none of the parameters work anyway

# %% [markdown]
# Calibration for blue screw attenuator was run for 300s. Same code as ID 18 (screw attenuator calibration) from cooldown 11.

# %%
load_by_id(99).get_parameter_data()['attenuation']['attenuation']
# Out:
# array([0.430669])

# %%
############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)
# Out:
# Laser enable status: True

# %%
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')
# Out:
# Laser enable status: False

# %%
############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

params.quick_check(pmeter10=pm100d, pmeter90=pms120, attenuator_name=params.att_yscrew_name)

############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')
# Out:
# Laser enable status: True
# update station
# Starting experimental run with id: 101.
# 101
# 2026-06-01 04:23:48,711 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# power10: 0.000408154301, power90: 0.00486300979, attenuation: 0.4309743363037165
# Laser enable status: False

# %%
############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

params.quick_check(pmeter10=pm100d, pmeter90=pms120, attenuator_name=params.att_yscrew_name)

############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')
# Out:
# Laser enable status: True
# update station
# Starting experimental run with id: 102.
# 102
# 2026-06-01 04:29:23,470 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# power10: 0.000410264154, power90: 0.0048912433, attenuation: 0.4337236006650624
# Laser enable status: False

# %%
############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

params.quick_check(pmeter10=pm100d, pmeter90=pms120, attenuator_name=params.att_screw_name)

############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')
# Out:
# Laser enable status: True
# update station
# Starting experimental run with id: 103.
# 103
# 2026-06-01 04:33:56,085 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# power10: 4.89370056e-09, power90: 0.00485778181, attenuation: 49.63817279560622
# Laser enable status: False

# %% [markdown]
# Blue screw attenuator is clearly working

# %%
############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

params.quick_check(pmeter10=pm100d, pmeter90=pms120, attenuator_name=params.att_yscrew_name)

############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')
# Out:
# Laser enable status: True
# update station
# Starting experimental run with id: 104.
# 104
# 2026-06-01 04:36:13,115 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# power10: 3.15871244e-12, power90: 0.00488078548, attenuation: 81.55996296267813
# Laser enable status: False

# %%
############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

params.quick_check(pmeter10=pm100d, pmeter90=pms120, attenuator_name=params.att_yscrew_name)

############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')
# Out:
# Laser enable status: True
# update station
# Starting experimental run with id: 105.
# 105
# 2026-06-01 04:36:52,074 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# power10: 7.15806948e-07, power90: 0.00487764878, attenuation: 28.00431282802222
# Laser enable status: False

# %%
############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

params.quick_check(pmeter10=pm100d, pmeter90=pms120, attenuator_name=params.att_yscrew_name)
# Out:
# Laser enable status: True
# update station
# Starting experimental run with id: 106.
# 106
# 2026-06-01 04:39:38,719 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# power10: 6.42358984e-08, power90: 0.00487242034, attenuation: 38.46983612049905

# %%
params.quick_check(pmeter10=pm100d, pmeter90=pms120, attenuator_name=params.att_yscrew_name)
# Out:
# update station
# Starting experimental run with id: 107.
# 107
# 2026-06-01 04:39:52,175 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# power10: 1.67336867e-09, power90: 0.00486928364, attenuation: 54.30890106833171

# %% [markdown]
# VOA1550 goes up to 48.74 dB (5V applied). Max we want to see is about 140dB, so we could choose 50dB for blue, 40dB for yellow and up to 50 for the voltage dependent one.

# %%
params.quick_check(pmeter10=pm100d, pmeter90=pms120, attenuator_name=params.att_yscrew_name)
# Out:
# update station
# Starting experimental run with id: 110.
# 110
# 2026-06-01 04:44:22,916 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# power10: 7.49339719e-08, power90: 0.00488496805, attenuation: 37.811996415168075

# %%
############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

params.quick_check(pmeter10=pm100d, pmeter90=pms120, attenuator_name=params.att_yscrew_name)

############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')
# Out:
# Laser enable status: True
# update station
# Starting experimental run with id: 112.
# 112
# 2026-06-01 04:45:50,353 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# power10: 8.41020338e-08, power90: 0.00487032905, attenuation: 37.29768472894081
# Laser enable status: False

# %%
############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

params.quick_check(pmeter10=pm100d, pmeter90=pms120, attenuator_name=params.att_yscrew_name)
# Out:
# Laser enable status: True
# update station
# Starting experimental run with id: 113.
# 113
# 2026-06-01 04:46:21,904 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# power10: 8.65356071e-08, power90: 0.00487346621, attenuation: 37.176597814562896

# %%
############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

params.quick_check(pmeter10=pm100d, pmeter90=pms120, attenuator_name=params.att_yscrew_name)
# Out:
# Laser enable status: True
# update station
# Starting experimental run with id: 114.
# 114
# 2026-06-01 04:46:45,748 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# power10: 3.31733077e-08, power90: 0.00487764878, attenuation: 41.34438415324409

# %%
params.quick_check(pmeter10=pm100d, pmeter90=pms120, attenuator_name=params.att_yscrew_name)
# Out:
# update station
# Starting experimental run with id: 115.
# 115
# 2026-06-01 04:47:02,258 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# power10: 5.37667226e-08, power90: 0.0048609185, attenuation: 39.232214422002905

# %%
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')
# Out:
# Laser enable status: False

# %%
############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)
# Out:
# Laser enable status: True

# %%
params.quick_check(pmeter10=pm100d, pmeter90=pms120, attenuator_name=params.att_yscrew_name)
# Out:
# update station
# Starting experimental run with id: 116.
# 116
# 2026-06-01 04:51:39,266 ¦ py.warnings ¦ WARNING ¦ warnings ¦ _showwarnmsg ¦ 110 ¦ C:\Users\QNL\anaconda3\envs\qcodes\Lib\site-packages\pyvisa\resources\messagebased.py:702: UserWarning: read string doesn't end with termination characters
#   return self.read()
# power10: 6.12031847e-09, power90: 0.00488078548, attenuation: 48.68732365872973

# %%
############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)
# Out:
# Laser enable status: True

# %%
############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

# %%
params.laser_set_standard(laser, wavelength=1550e-9, power=7)
params.laser_get_standard(laser)
params.pmeter_set_standard(pmeter=pm100d, wavelength=1550e-9)
params.pmeter_set_standard(pmeter=pms120, wavelength=1550e-9)


############################ TURN LASER ON ############################ 
laser.enable(True)
print(f'Laser enable status: {laser.enable()}')
time.sleep(10)

params.calibrate(t=300, pmeter10=pm100d, pmeter90=pms120, attenuator_name=params.att_yscrew_name)

############################ TURN LASER OFF ############################ 
laser.enable(False)
print(f'Laser enable status: {laser.enable()}')

# %%
laser.enable()
# Out:
# False
